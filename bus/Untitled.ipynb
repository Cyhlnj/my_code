# %%
import pandas as pd

# %%
import MySQLdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-1ca246cdd999> in <module>()
# ----> 1 import MySQLdb
#
# ModuleNotFoundError: No module named 'MySQLdb'

# %%
import pymysql
conn = pymysql.Connect(
    host='localhost',
    port=3306,
    user='root',
    passwd='',
    db='mysql',
    charset='utf8',
)
cursor = conn.cursor()
sql = "select sitename, line_num from mysql.Bus ORDER BY Line_Num DESC"
cursor.execute(sql)
# 获取查询结果
result = cursor.fetchall()
result
# Out:
# (('密云汽车站', 55),
#  ('刘林池', 52),
#  ('客运总站', 47),
#  ('六里桥东', 45),
#  ('密云妇幼保健院', 41),
#  ('平谷劳务市场', 41),
#  ('平谷汽车站', 39),
#  ('六里桥北里', 37),
#  ('黄村', 37),
#  ('静安庄', 36),
#  ('鼓楼南站', 35),
#  ('丰台路口', 35),
#  ('环保局', 34),
#  ('侯庄子', 33),
#  ('首都机场3号航站楼', 31),
#  ('木樨园桥西', 31),
#  ('郎家园', 31),
#  ('河北村', 31),
#  ('怀柔汽车站', 31),
#  ('康居南区', 29),
#  ('京客隆', 29),
#  ('木樨园桥东', 28),
#  ('柳树沟', 28),
#  ('李老新村', 28),
#  ('马甸桥南', 27),
#  ('九棵树', 27),
#  ('海淀黄庄北', 27),
#  ('华云路口', 27),
#  ('广安门内', 27),
#  ('平谷中医医院', 26),
#  ('亮马桥', 26),
#  ('构件厂', 26),
#  ('南彩工业园', 25),
#  ('丽泽桥', 25),
#  ('黄村东大街东口', 25),
#  ('马甸桥东', 24),
#  ('看丹桥', 24),
#  ('航天桥西', 24),
#  ('高米店', 24),
#  ('俸伯小学', 24),
#  ('穆家峪路口', 23),
#  ('鲁各庄', 23),
#  ('莲花池', 23),
#  ('抗战雕塑园', 23),
#  ('广宁村', 23),
#  ('房山火车站', 23),
#  ('南法信', 22),
#  ('南彩汽车站', 22),
#  ('南坞', 22),
#  ('麻峪北口', 22),
#  ('金安桥西', 22),
#  ('蓟门桥西', 22),
#  ('怀柔五中', 22),
#  ('和平西桥', 22),
#  ('化纤俱乐部', 22),
#  ('广顺桥南', 22),
#  ('公路局', 22),
#  ('达官营', 22),
# ...

# %%
import matplotlib

# %%
import pyecharts
import pandas as pd

x_data = list(result[0:1000])
x = x_data[0][:]
# y_data = result[1:5]

# from pyecharts import Bar
# bar = Bar()
# bar.add('top_director',x_data,y_data)
# bar
